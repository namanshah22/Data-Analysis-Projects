# %% [markdown]
# ![trainers in a store](trainers.jpg)
#
# Sports clothing and athleisure attire is a huge industry, worth approximately [$193 billion in 2021](https://www.statista.com/statistics/254489/total-revenue-of-the-global-sports-apparel-market/) with a strong growth forecast over the next decade!
#
# In this notebook, you will undertake the role of a product analyst for an online sports clothing company. The company is specifically interested in how it can improve revenue. You will dive into product data such as pricing, reviews, descriptions, and ratings, as well as revenue and website traffic, to produce recommendations for its marketing and sales teams.
#
# You've been provided with four datasets to investigate:
#
# #  brands.csv
#
# | Columns | Description |
# |---------|-------------|
# | `product_id` | Unique product identifier |
# | `brand` | Brand of the product |
#
# # finance.csv
#
# | Columns | Description |
# |---------|-------------|
# | `product_id` | Unique product identifier |
# | `listing_price` | Original price of the product |
# | `sale_price` | Discounted price of the product |
# | `discount` | Discount off the listing price, as a decimal |
# | `revenue` | Revenue generated by the product |
#
# # info.csv
#
# | Columns | Description |
# |---------|-------------|
# | `product_name` | Name of the product |
# | `product_id` | Unique product identifier |
# | `description` | Description of the product |
#
# # reviews.csv
#
# | Columns | Description |
# |---------|-------------|
# | `product_id` | Unique product identifier |
# | `rating` | Average product rating |
# | `reviews` | Number of reviews for the product |

# %%
import pandas as pd

brands = pd.read_csv("brands.csv") 
finance = pd.read_csv("finance.csv")
info = pd.read_csv("info.csv")
reviews = pd.read_csv("reviews.csv")

# %%
merged_df=info.merge(finance,on="product_id",how="outer")
merged_df=merged_df.merge(reviews,on="product_id",how="outer")
merged_df=merged_df.merge(brands,on="product_id",how="outer")
merged_df.head()
# Out:
#                                        product_name product_id  ... reviews   brand
# 0                                               NaN     AH2430  ...     NaN     NaN
# 1              Women's adidas Originals Sleek Shoes     G27341  ...    24.0  Adidas
# 2                 Women's adidas Swim Puka Slippers     CM0081  ...    37.0  Adidas
# 3  Women's adidas Sport Inspired Questar Ride Shoes     B44832  ...    35.0  Adidas
# 4          Women's adidas Originals Taekwondo Shoes     D98205  ...    72.0  Adidas
#
# [5 rows x 10 columns]

# %%
merged_df.dropna(inplace=True)
merged_df.head()
# Out:
#                                         product_name  ...   brand
# 1               Women's adidas Originals Sleek Shoes  ...  Adidas
# 2                  Women's adidas Swim Puka Slippers  ...  Adidas
# 3   Women's adidas Sport Inspired Questar Ride Shoes  ...  Adidas
# 4           Women's adidas Originals Taekwondo Shoes  ...  Adidas
# 5  Women's adidas Sport Inspired Duramo Lite 2.0 ...  ...  Adidas
#
# [5 rows x 10 columns]

# %% [markdown]
# What is the volume of products and average revenue for Adidas and Nike products based on listing price quartiles?

# %%
merged_df["price_label"]=pd.qcut(merged_df["listing_price"],q=4,labels=["Budget","Average","Expensive","Elite"])

# %%
merged_df
# Out:
#                                            product_name  ... price_label
# 1                  Women's adidas Originals Sleek Shoes  ...   Expensive
# 2                     Women's adidas Swim Puka Slippers  ...      Budget
# 3      Women's adidas Sport Inspired Questar Ride Shoes  ...   Expensive
# 4              Women's adidas Originals Taekwondo Shoes  ...   Expensive
# 5     Women's adidas Sport Inspired Duramo Lite 2.0 ...  ...     Average
# ...                                                 ...  ...         ...
# 3174                    Nike Tiempo Legend 8 Academy TF  ...      Budget
# 3175                              Nike React Metcon AMP  ...      Budget
# 3176                                 Air Jordan 8 Retro  ...       Elite
# 3177                                    Nike Air Max 98  ...      Budget
# 3178                                     Nike P-6000 SE  ...   Expensive
#
# [3117 rows x 11 columns]

# %% [markdown]
# This function pd.qcut divides the values in the "listing_price" column into four equal-sized bins or quartiles (q=4). It assigns a label to each bin based on the provided labels list. The lowest values will be labeled as "Budget," the next quartile as "Average," the third quartile as "Expensive," and the highest quartile as "Elite."

# %%
adidas_vs_nike = merged_df.groupby(["brand", "price_label"], as_index=False).agg(
    num_products=("price_label", "count"), 
    mean_revenue=("revenue", "mean")
).round(2).reset_index(drop=True)

# %% [markdown]
# The parameter drop=True ensures that the previous index is not included

# %%
adidas_vs_nike.head()
# Out:
#     brand price_label  num_products  mean_revenue
# 0  Adidas      Budget           574       2015.68
# 1  Adidas     Average           655       3035.30
# 2  Adidas   Expensive           759       4621.56
# 3  Adidas       Elite           587       8302.78
# 4    Nike      Budget           357       1596.33

# %% [markdown]
# What is the volume of products and average revenue for Adidas and Nike products based on listing price quartiles?

# %%
merged_df["description_length"]=merged_df["description"].str.len()
merged_df["description_length"]
# Out:
# 1       175
# 2       172
# 3       264
# 4       288
# 5       221
#        ...
# 3174    146
# 3175    378
# 3176    204
# 3177    240
# 3178    202
# Name: description_length, Length: 3117, dtype: int64

# %%
max(merged_df["description_length"])
# Out:
# 687

# %%
# Upper description length limits
lengthes = [0, 100, 200, 300, 400, 500, 600, 700]

# %%
labels = ["100", "200", "300", "400", "500", "600", "700"]

# %%
merged_df["description_length"] = pd.cut(merged_df["description_length"], bins=lengthes, labels=labels)

# %%
merged_df.head()
# Out:
#                                         product_name  ... description_length
# 1               Women's adidas Originals Sleek Shoes  ...                200
# 2                  Women's adidas Swim Puka Slippers  ...                200
# 3   Women's adidas Sport Inspired Questar Ride Shoes  ...                300
# 4           Women's adidas Originals Taekwondo Shoes  ...                300
# 5  Women's adidas Sport Inspired Duramo Lite 2.0 ...  ...                300
#
# [5 rows x 12 columns]

# %%
description_length=merged_df.groupby("description_length",as_index=False).agg(mean_rating=("rating","mean"),num_reviews=("reviews","count")).round(2)

# %%
description_length
# Out:
#   description_length  mean_rating  num_reviews
# 0                100         2.26            7
# 1                200         3.19          526
# 2                300         3.28         1785
# 3                400         3.29          651
# 4                500         3.35          118
# 5                600         3.12           15
# 6                700         3.65           15

# %%
mylist = "shoe*|trainer*|foot*"

# %%
shoes = merged_df[merged_df["description"].str.contains(mylist)]

# %%
shoes
# Out:
#                                            product_name  ... description_length
# 1                  Women's adidas Originals Sleek Shoes  ...                200
# 2                     Women's adidas Swim Puka Slippers  ...                200
# 3      Women's adidas Sport Inspired Questar Ride Shoes  ...                300
# 4              Women's adidas Originals Taekwondo Shoes  ...                300
# 5     Women's adidas Sport Inspired Duramo Lite 2.0 ...  ...                300
# ...                                                 ...  ...                ...
# 3168                         Nike Zoom Pegasus Turbo XX  ...                500
# 3169                                   Nike Air Max 200  ...                300
# 3171                    Nike Mercurial Vapor 13 Club MG  ...                200
# 3173                                 Air Jordan 5 Retro  ...                300
# 3175                              Nike React Metcon AMP  ...                400
#
# [2639 rows x 12 columns]

# %%
clothing = merged_df[~merged_df.isin(shoes["product_id"])]

# %%
clothing
# Out:
#                                            product_name  ... description_length
# 1                  Women's adidas Originals Sleek Shoes  ...                200
# 2                     Women's adidas Swim Puka Slippers  ...                200
# 3      Women's adidas Sport Inspired Questar Ride Shoes  ...                300
# 4              Women's adidas Originals Taekwondo Shoes  ...                300
# 5     Women's adidas Sport Inspired Duramo Lite 2.0 ...  ...                300
# ...                                                 ...  ...                ...
# 3174                    Nike Tiempo Legend 8 Academy TF  ...                200
# 3175                              Nike React Metcon AMP  ...                400
# 3176                                 Air Jordan 8 Retro  ...                300
# 3177                                    Nike Air Max 98  ...                300
# 3178                                     Nike P-6000 SE  ...                300
#
# [3117 rows x 12 columns]

# %%
clothing.dropna(inplace=True)
clothing
# Out:
#                                    product_name  ... description_length
# 71            Men's adidas Toe Side II Slippers  ...                300
# 100       Men's adidas Running Nepton 2.0 Shoes  ...                300
# 105           Men's adidas Toe Side II Slippers  ...                300
# 114       Men's adidas Running Nepton 2.0 Shoes  ...                300
# 136         Women's Originals Sleek Super Shoes  ...                200
# ...                                         ...  ...                ...
# 3172  Nike Zoom Pegasus Turbo 2 Special Edition  ...                200
# 3174            Nike Tiempo Legend 8 Academy TF  ...                200
# 3176                         Air Jordan 8 Retro  ...                300
# 3177                            Nike Air Max 98  ...                300
# 3178                             Nike P-6000 SE  ...                300
#
# [478 rows x 12 columns]

# %%
product_types = pd.DataFrame({"num_clothing_products": len(clothing), 
                        "median_clothing_revenue":clothing["revenue"].median(), 
                              "num_footwear_products": len(shoes), 
                        "median_footwear_revenue":shoes["revenue"].median()}, 
                              index=[0])

# %%
product_types
# Out:
#    num_clothing_products  ...  median_footwear_revenue
# 0                    478  ...                   3073.3
#
# [1 rows x 4 columns]
